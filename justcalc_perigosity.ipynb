# %%
dem = '/home/jasp/bedsburning/dem_ctr.tif'

ws = '/home/jasp/bedsburning'

out_susc = '/mnt/x/firebeds_tk1/results2/res_lri.tif'

out_prob = '/mnt/x/firebeds_tk1/results2/wprobability.tif'

out_peri = '/mnt/x/firebeds_tk1/results2/res_perigosity.tif'

# %%
from glass.ete.lri import HeuristicLri

# %%
lri = HeuristicLri(ws, dem, loc=None)

# %%
# Generate perigosity
lri.get_perigosity(
    inlri=out_susc, wildprob=out_prob,
    out=out_peri
)
