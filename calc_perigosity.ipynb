# %%
dem = '/home/jasp/bedsburning/dem_ctr.tif'

ws = '/home/jasp/bedsburning'

bareas = '/mnt/h/firebeds_tk1/aa/rst_aa_all.tif'
bareas_by_year = '/mnt/h/firebeds_tk1/aa_clip'

_vars = {
    'dem'    : '/mnt/h/firebeds_tk1/vars/ctr_lri_var_dem.tif',
    'slope'  : '/mnt/h/firebeds_tk1/vars/ctr_lri_var_slope.tif',
    'aspect' : '/mnt/h/firebeds_tk1/vars/ctr_lri_var_aspect.tif'
}

lulcs = [
    '/mnt/h/firebeds_tk1/cos_ctr/cos15.tif',
    '/mnt/h/firebeds_tk1/cos_ctr/cos15_1.tif',
    '/mnt/h/firebeds_tk1/cos_ctr/cos15_2.tif',
    '/mnt/h/firebeds_tk1/cos_ctr/cos18.tif',
    '/mnt/h/firebeds_tk1/cos_ctr/cos18_1.tif',
    '/mnt/h/firebeds_tk1/cos_ctr/cos20.tif',
    '/mnt/h/firebeds_tk1/cos_ctr/cos21.tif',
    '/mnt/h/firebeds_tk1/cos_ctr/cos22.tif',
    '/mnt/h/firebeds_tk1/cos_ctr/cos23.tif'
]

burncos = [
    '/mnt/h/firebeds_tk1/aa_rst/rst_ardida_2015.tif',
    '/mnt/h/firebeds_tk1/aa_rst/rst_ardida_2016.tif',
    '/mnt/h/firebeds_tk1/aa_rst/rst_ardida_2017.tif',
    '/mnt/h/firebeds_tk1/aa_rst/rst_ardida_2018.tif',
    '/mnt/h/firebeds_tk1/aa_rst/rst_ardida_2019.tif',
    '/mnt/h/firebeds_tk1/aa_rst/rst_ardida_2020.tif',
    '/mnt/h/firebeds_tk1/aa_rst/rst_ardida_2021.tif',
    '/mnt/h/firebeds_tk1/aa_rst/rst_ardida_2022.tif',
    '/mnt/h/firebeds_tk1/aa_rst/rst_ardida_2023.tif',
]

out_susc = '/mnt/h/firebeds_tk1/results2/res_lri.tif'

out_prob = '/mnt/h/firebeds_tk1/results2/wprobability.tif'

out_peri = '/mnt/h/firebeds_tk1/results2/res_perigosity.tif'

# %%
import os
from glass.ete.lri import HeuristicLri

# %%
lri = HeuristicLri(ws, dem, loc=None)

# %%
# Import topographic variables

lri.import_topo_vars(dem=_vars['dem'], slope=_vars['slope'], aspect=_vars['aspect'])

# Import events
lri.import_events(bareas)

# %%
# Import LULC variables
lri.import_lulc_vars(lulcs, [1 for x in lulcs], burncos)

# %%
# Generate LRI
lri_res = lri.calc_lri(out=out_susc)

# %%
lri.export_vars_lri(os.path.dirname(out_susc), 'lri')

# %%
# Generate Wildfire probability
wprob = lri.wildfire_probability(bareas_by_year, out=out_prob)

# %%
# Generate perigosity
lri.get_perigosity(out=out_peri)
